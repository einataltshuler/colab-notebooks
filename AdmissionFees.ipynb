# %% [markdown]
# <a href="https://colab.research.google.com/github/einataltshuler/colab-notebooks/blob/main/AdmissionFees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# water park admission fees
# input
intAge = int(input("How old are you? "))

if intAge < 0:
  print("Re-enter the input.")
elif intAge <  13:
  print("$8")
elif intAge <= 17:
  print(f"{intAge} -> $10")
elif intAge <= 125:
  print("12")
else:
  print("You cannot enter a number higher than 125.")
# Out:
# How old are you? 17
# 17 -> $10

# %%
age = float(input)
